# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
dataframe = pd.read_csv('Inference_Results.csv')

# %%
fig, axs = plt.subplots(2, 2, tight_layout=True)
data1=dataframe[((dataframe['Model']=="ResNet") | (dataframe['Model']=="ResNet SPTQ") | (dataframe['Model']=="ResNet QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data2=dataframe[((dataframe['Model']=="ResNext") | (dataframe['Model']=="ResNext SPTQ") | (dataframe['Model']=="ResNext QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data3=dataframe[((dataframe['Model']=="Bert") | (dataframe['Model']=="Bert SPTQ") | (dataframe['Model']=="Bert QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data4=dataframe[((dataframe['Model']=="Roberta") | (dataframe['Model']=="Roberta SPTQ") | (dataframe['Model']=="Roberta QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
ymax=math.ceil(max(data1['Inference'].max(), data2['Inference'].max()))
ymax1=math.ceil(max(data3['Inference'].max(), data4['Inference'].max()))
sns.boxplot(data=data1,x="Device",y="Inference",hue="Model",ax=axs[0][0], linewidth=0.8,hue_order=["ResNet","ResNet SPTQ","ResNet QAT"],order=["Mobile","Edge","Cloud"])
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('(s)')
axs[0][0].set_ylim(([0, ymax]))
handles,_=axs[0][0].get_legend_handles_labels()
fig.legend(handles,["Identity","SPTQ","QAT"],loc='upper center',ncol=4,fontsize=10,bbox_to_anchor=(0.5, 1.07))
sns.boxplot(data=data2,x="Device",y="Inference",hue="Model",ax=axs[0][1], linewidth=0.8,hue_order=["ResNext","ResNext SPTQ","ResNext QAT"],order=["Mobile","Edge","Cloud"])
axs[0][1].set_title('ResNext')
axs[0][1].set_ylabel('(s)')
axs[0][1].set_ylim(([0, ymax]))
sns.boxplot(data=data3,x="Device",y="Inference",hue="Model",ax=axs[1][0], linewidth=0.8,hue_order=["Bert","Bert SPTQ","Bert QAT"],order=["Mobile","Edge","Cloud"])
axs[1][0].set_title('Bert')
axs[1][0].set_ylabel('(s)')
axs[1][0].set_ylim(([0, ymax1]))
sns.boxplot(data=data4,x="Device",y="Inference",hue="Model",ax=axs[1][1], linewidth=0.8,hue_order=["Roberta","Roberta SPTQ","Roberta QAT"],order=["Mobile","Edge","Cloud"])
axs[1][1].set_title('Roberta')
axs[1][1].set_ylabel('(s)')
axs[1][1].set_ylim(([0, ymax1]))
axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
axs[1][0].get_legend().remove()
axs[1][1].get_legend().remove()
plt.show()
fig.savefig('img_rq1_results.pdf', bbox_inches='tight',format='pdf')

# %%
fig, axs = plt.subplots(2, 2, tight_layout=True)
data1=dataframe[((dataframe['Model']=="ResNet") | (dataframe['Model']=="ResNet Pruned")| (dataframe['Model']=="ResNet SPTQ") | (dataframe['Model']=="ResNet QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data2=dataframe[((dataframe['Model']=="ResNext")| (dataframe['Model']=="ResNext Pruned") | (dataframe['Model']=="ResNext SPTQ") | (dataframe['Model']=="ResNext QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data3=dataframe[((dataframe['Model']=="Bert") | (dataframe['Model']=="Bert Pruned") | (dataframe['Model']=="Bert SPTQ") | (dataframe['Model']=="Bert QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data4=dataframe[((dataframe['Model']=="Roberta") | (dataframe['Model']=="Roberta Pruned") | (dataframe['Model']=="Roberta SPTQ") | (dataframe['Model']=="Roberta QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
ymax=math.ceil(max(data1['Inference'].max(), data2['Inference'].max()))
ymax1=math.ceil(max(data3['Inference'].max(), data4['Inference'].max()))
sns.boxplot(data=data1,x="Device",y="Inference",hue="Model",ax=axs[0][0], linewidth=0.8,hue_order=["ResNet","ResNet Pruned","ResNet SPTQ","ResNet QAT"],order=["Mobile","Edge","Cloud"])
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('(s)')
axs[0][0].set_ylim(([0, ymax]))
handles,_=axs[0][0].get_legend_handles_labels()
fig.legend(handles,["Identity","Pruned","SPTQ","QAT"],loc='upper center',ncol=4,fontsize=10,bbox_to_anchor=(0.5, 1.07))
sns.boxplot(data=data2,x="Device",y="Inference",hue="Model",ax=axs[0][1], linewidth=0.8,hue_order=["ResNext","ResNext Pruned","ResNext SPTQ","ResNext QAT"],order=["Mobile","Edge","Cloud"])
axs[0][1].set_title('ResNext')
axs[0][1].set_ylabel('(s)')
axs[0][1].set_ylim(([0, ymax]))
sns.boxplot(data=data3,x="Device",y="Inference",hue="Model",ax=axs[1][0], linewidth=0.8,hue_order=["Bert","Bert Pruned","Bert SPTQ","Bert QAT"],order=["Mobile","Edge","Cloud"])
axs[1][0].set_title('Bert')
axs[1][0].set_ylabel('(s)')
axs[1][0].set_ylim(([0, ymax1]))
sns.boxplot(data=data4,x="Device",y="Inference",hue="Model",ax=axs[1][1], linewidth=0.8,hue_order=["Roberta","Roberta Pruned","Roberta SPTQ","Roberta QAT"],order=["Mobile","Edge","Cloud"])
axs[1][1].set_title('Roberta')
axs[1][1].set_ylabel('(s)')
axs[1][1].set_ylim(([0, ymax1]))
axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
axs[1][0].get_legend().remove()
axs[1][1].get_legend().remove()
plt.show()
fig.savefig('img_rq2_results.pdf', bbox_inches='tight',format='pdf')

# %%
fig, axs = plt.subplots(2, 2, tight_layout=True)
data1=dataframe[((dataframe['Model']=="ResNet") | (dataframe['Model']=="ResNet Distilled") | (dataframe['Model']=="ResNet Pruned") | (dataframe['Model']=="ResNet SPTQ")| (dataframe['Model']=="ResNet QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data2=dataframe[((dataframe['Model']=="ResNext") | (dataframe['Model']=="ResNext Distilled") | (dataframe['Model']=="ResNext Pruned") | (dataframe['Model']=="ResNext SPTQ")| (dataframe['Model']=="ResNext QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data3=dataframe[((dataframe['Model']=="Bert") | (dataframe['Model']=="Bert Distilled") | (dataframe['Model']=="Bert Pruned") |(dataframe['Model']=="Bert SPTQ")| (dataframe['Model']=="Bert QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
data4=dataframe[((dataframe['Model']=="Roberta") | (dataframe['Model']=="Roberta Distilled") | (dataframe['Model']=="Roberta Pruned") |(dataframe['Model']=="Roberta SPTQ")| (dataframe['Model']=="Roberta QAT")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]
ymax=math.ceil(max(data1['Inference'].max(), data2['Inference'].max()))
ymax1=math.ceil(max(data3['Inference'].max(), data4['Inference'].max()))
sns.boxplot(data=data1,x="Device",y="Inference",hue="Model",ax=axs[0][0], linewidth=0.8,hue_order=["ResNet","ResNet Distilled","ResNet Pruned","ResNet SPTQ","ResNet QAT"],order=["Mobile","Edge","Cloud"])
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('(s)')
axs[0][0].set_ylim(([0, ymax]))
handles,_=axs[0][0].get_legend_handles_labels()
fig.legend(handles,["Identity","Distilled","Pruned","SPTQ","QAT"],loc='upper center',ncol=5,fontsize=10,bbox_to_anchor=(0.5, 1.07))
sns.boxplot(data=data2,x="Device",y="Inference",hue="Model",ax=axs[0][1], linewidth=0.8,hue_order=["ResNext","ResNext Distilled","ResNext Pruned","ResNext SPTQ","ResNext QAT"],order=["Mobile","Edge","Cloud"])
axs[0][1].set_title('ResNext')
axs[0][1].set_ylabel('(s)')
axs[0][1].set_ylim(([0, ymax]))
sns.boxplot(data=data3,x="Device",y="Inference",hue="Model",ax=axs[1][0], linewidth=0.8,hue_order=["Bert","Bert Distilled","Bert Pruned","Bert SPTQ","Bert QAT"],order=["Mobile","Edge","Cloud"])
axs[1][0].set_title('Bert')
axs[1][0].set_ylabel('(s)')
axs[1][0].set_ylim(([0, ymax1]))
sns.boxplot(data=data4,x="Device",y="Inference",hue="Model",ax=axs[1][1], linewidth=0.8,hue_order=["Roberta","Roberta Distilled","Roberta Pruned","Roberta SPTQ","Roberta QAT"],order=["Mobile","Edge","Cloud"])
axs[1][1].set_title('Roberta')
axs[1][1].set_ylabel('(s)')
axs[1][1].set_ylim(([0, ymax1]))
axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
axs[1][0].get_legend().remove()
axs[1][1].get_legend().remove()
plt.show()
fig.savefig('img_rq3_results.pdf', bbox_inches='tight',format='pdf')

# %%
fig, axs = plt.subplots(2, 2, tight_layout=True)
x_labels=['M','E','C','ME']
data1=dataframe[((dataframe['Model']=="ResNet") | (dataframe['Model']=="ResNet Pruned") |(dataframe['Model']=="ResNet QAT") | (dataframe['Model']=="ResNet SPTQ") | (dataframe['Model']=="ResNet Distilled")| (dataframe['Model']=="ResNet Distilled SPTQ")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud") | (dataframe['Device']=="Mobile-Edge"))]
data2=dataframe[((dataframe['Model']=="ResNext")| (dataframe['Model']=="ResNext Pruned") | (dataframe['Model']=="ResNext QAT") | (dataframe['Model']=="ResNext SPTQ") |(dataframe['Model']=="ResNext Distilled") | (dataframe['Model']=="ResNext Distilled SPTQ")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud")| (dataframe['Device']=="Mobile-Edge"))]
data3=dataframe[((dataframe['Model']=="Bert") | (dataframe['Model']=="Bert Pruned") | (dataframe['Model']=="Bert QAT") | (dataframe['Model']=="Bert SPTQ") | (dataframe['Model']=="Bert Distilled") | (dataframe['Model']=="Bert Distilled SPTQ")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud")| (dataframe['Device']=="Mobile-Edge"))]
data4=dataframe[((dataframe['Model']=="Roberta") | (dataframe['Model']=="Roberta Pruned") |(dataframe['Model']=="Roberta QAT") | (dataframe['Model']=="Roberta SPTQ") | (dataframe['Model']=="Roberta Distilled") | (dataframe['Model']=="Roberta Distilled SPTQ")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud")| (dataframe['Device']=="Mobile-Edge"))]
ymax=math.ceil(max(data1['Inference'].max(), data2['Inference'].max()))
ymax1=math.ceil(max(data3['Inference'].max(), data4['Inference'].max()))
sns.boxplot(data=data1,x="Device",y="Inference",hue="Model",ax=axs[0][0], linewidth=0.8,hue_order=["ResNet","ResNet QAT","ResNet SPTQ","ResNet Pruned","ResNet Distilled","ResNet Distilled SPTQ"],order=["Mobile","Edge","Cloud","Mobile-Edge"])
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('(s)')
axs[0][0].set_ylim(([0, ymax]))
axs[0][0].set_xticklabels(x_labels)
handles,_=axs[0][0].get_legend_handles_labels()
fig.legend(handles,["I","QAT","SPTQ","Pruned","Distilled","DSPTQ"],loc='upper center',ncol=7,fontsize=10,bbox_to_anchor=(0.5, 1.07))
sns.boxplot(data=data2,x="Device",y="Inference",hue="Model",ax=axs[0][1], linewidth=0.8,hue_order=["ResNext","ResNext QAT","ResNext SPTQ","ResNext Pruned","ResNext Distilled","ResNext Distilled SPTQ"],order=["Mobile","Edge","Cloud","Mobile-Edge"])
axs[0][1].set_title('ResNext')
axs[0][1].set_ylabel('(s)')
axs[0][1].set_ylim(([0, ymax]))
axs[0][1].set_xticklabels(x_labels)
sns.boxplot(data=data3,x="Device",y="Inference",hue="Model",ax=axs[1][0], linewidth=0.8,hue_order=["Bert","Bert QAT","Bert SPTQ","Bert Pruned","Bert Distilled","Bert Distilled SPTQ"],order=["Mobile","Edge","Cloud","Mobile-Edge"])
axs[1][0].set_title('Bert')
axs[1][0].set_ylabel('(s)')
axs[1][0].set_ylim(([0, ymax1]))
axs[1][0].set_xticklabels(x_labels)
sns.boxplot(data=data4,x="Device",y="Inference",hue="Model",ax=axs[1][1], linewidth=0.8,hue_order=["Roberta","Roberta QAT","Roberta SPTQ","Roberta Pruned","Roberta Distilled","Roberta Distilled SPTQ"],order=["Mobile","Edge","Cloud","Mobile-Edge"])
axs[1][1].set_title('Roberta')
axs[1][1].set_ylabel('(s)')
axs[1][1].set_ylim(([0, ymax1]))
axs[1][1].set_xticklabels(x_labels)
axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
axs[1][0].get_legend().remove()
axs[1][1].get_legend().remove()
plt.show()
fig.savefig('img_rq4_results.pdf', bbox_inches='tight',format='pdf')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for the first subplot
data_dict = {}
data_dict['category'] = ['Identity','QAT','SPTQ','Pruned']
data_dict['lower'] = [1.76, 2.49, 2.1, 1.70]
data_dict['upper'] = [4.73, 3.38, 3.29, 4.73]
data_dict['median'] = [3.39, 3.36, 2.94, 3.34]
dataset = pd.DataFrame(data_dict)

# Data for the second subplot
data_dict1 = {}
data_dict['category'] = ['Identity','QAT','SPTQ','Pruned']
data_dict1['lower'] = [1.78, 2.30, 1.09, 1.74]
data_dict1['upper'] = [4.57, 3.57, 2.26, 4.41]
data_dict1['median'] =[3.39, 2.66, 1.90, 3.31]
dataset1 = pd.DataFrame(data_dict1)

# Data for the third subplot
data_dict2 = {}
data_dict['category']=['Identity','QAT','SPTQ','Pruned']
data_dict2['lower'] = [2.46, 1.77, 1.16, 2.46]
data_dict2['upper'] = [3.23, 2.19, 0.97, 3.14]
data_dict2['median'] =[2.84, 1.98, 1.09, 2.8]
dataset2 = pd.DataFrame(data_dict2)

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(10, 4))

# Plot for the first subplot
axs[0].set_title('Mobile (All subject models)')
for lower, upper, median, y in zip(dataset['lower'], dataset['upper'], dataset['median'], range(len(dataset))):
    axs[0].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[0].plot(median, y, 'o', color='#f44336')
axs[0].set_yticks(range(len(dataset)))
axs[0].set_yticklabels(dataset['category'])
axs[0].set_xlabel('Distilled Speedup')
axs[0].set_xlim(1, 5)

# Plot for the second subplot
axs[1].set_title('Edge (All subject models)')
for lower, upper, median, y in zip(dataset1['lower'], dataset1['upper'], dataset1['median'], range(len(dataset1))):
    axs[1].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[1].plot(median, y, 'o', color='#f44336')
axs[1].set_yticks(range(len(dataset1)))
axs[1].set_yticklabels(dataset['category'])
axs[1].set_xlabel('Distilled Speedup')
axs[1].set_xlim(1, 5)

# Plot for the third subplot
axs[2].set_title('Cloud (Textual subject models)')
for lower, upper, median, y in zip(dataset2['lower'], dataset2['upper'], dataset2['median'], range(len(dataset2))):
    axs[2].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[2].plot(median, y, 'o', color='#f44336')
axs[2].set_yticks(range(len(dataset2)))
axs[2].set_yticklabels(dataset['category'])
axs[2].set_xlabel('Distilled Speedup')
axs[2].set_xlim(1, 5)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
fig.savefig('Distilled_Speedup.pdf', bbox_inches='tight',format='pdf')
# Out:
# <ipython-input-1-2bbdfe79418f>:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[0].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-1-2bbdfe79418f>:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[1].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-1-2bbdfe79418f>:54: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[2].plot((lower, upper), (y, y), 'ro-', color='orange')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for the first subplot
data_dict = {}
data_dict['category'] = ['Distilled','SPTQ', 'QAT', 'Pruned', 'Identity']
data_dict['lower'] = [0.76,1.91, 2.27, 1.54, 1.60]
data_dict['upper'] = [1.47,4.32, 4.81, 6.22, 6.39]
data_dict['median'] = [1.11,3.34, 3.7, 4.04, 4.08]
dataset = pd.DataFrame(data_dict)

# Data for the second subplot
data_dict1 = {}
data_dict1['category'] = ['Distilled','SPTQ', 'QAT', 'Pruned', 'Identity']
data_dict1['lower'] = [1.07, 1.65, 3.52, 2.63, 2.68]
data_dict1['upper'] = [1.76, 3.91, 4.31, 7.79, 8.07]
data_dict1['median'] = [1.52, 2.89, 3.93, 5.17, 5.29]
dataset1 = pd.DataFrame(data_dict1)

# Data for the third subplot
data_dict2 = {}
data_dict2['category'] = ['Distilled','SPTQ', 'QAT', 'Pruned', 'Identity']
data_dict2['lower'] = [2.36, 2.74, 5.14, 7.16, 7.14]
data_dict2['upper'] = [2.90, 2.80, 5.19, 7.44, 7.65]
data_dict2['median'] = [2.63, 2.77, 5.16, 7.30, 7.40]
dataset2 = pd.DataFrame(data_dict2)

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(10, 4))

# Plot for the first subplot
axs[0].set_title('Mobile (All subject models)')
for lower, upper, median, y in zip(dataset['lower'], dataset['upper'], dataset['median'], range(len(dataset))):
    axs[0].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[0].plot(median, y, 'o', color='#f44336')
axs[0].axvline(x=1, color='red', linestyle='--')
axs[0].set_yticks(range(len(dataset)))
axs[0].set_yticklabels(dataset['category'])
axs[0].set_xlabel('DSPTQ Speedup/Slowdown')
axs[0].set_xlim(0, 9)
axs[0].axvline(x=1, color='red', linestyle='--')

# Plot for the second subplot
axs[1].set_title('Edge (All subject models)')
for lower, upper, median, y in zip(dataset1['lower'], dataset1['upper'], dataset1['median'], range(len(dataset1))):
    axs[1].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[1].plot(median, y, 'o', color='#f44336')
axs[1].axvline(x=1, color='red', linestyle='--')
axs[1].set_yticks(range(len(dataset1)))
axs[1].set_yticklabels(dataset1['category'])
axs[1].set_xlabel('DSPTQ Speedup')
axs[1].set_xlim(0, 9)
axs[1].axvline(x=1, color='red', linestyle='--')

# Plot for the third subplot
axs[2].set_title('Cloud (Textual subject models)')
for lower, upper, median, y in zip(dataset2['lower'], dataset2['upper'], dataset2['median'], range(len(dataset2))):
    axs[2].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[2].plot(median, y, 'o', color='#f44336')
axs[2].axvline(x=1, color='red', linestyle='--')
axs[2].set_yticks(range(len(dataset2)))
axs[2].set_yticklabels(dataset2['category'])
axs[2].set_xlabel('DSPTQ Speedup')
axs[2].set_xlim(0, 9)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
fig.savefig('DSPTQ_Speedup.pdf', bbox_inches='tight',format='pdf')
# Out:
# <ipython-input-2-77bb36154576>:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[0].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-2-77bb36154576>:46: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[1].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-2-77bb36154576>:58: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[2].plot((lower, upper), (y, y), 'ro-', color='orange')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for the first subplot
data_dict = {}
data_dict['category'] = ['Identity','QAT','SPTQ','Pruned','*Distilled','DSPTQ']
data_dict['lower'] = [1.11, 1.18, 1.14, 1.20,0.63,1.14]
data_dict['upper'] = [1.72, 1.97, 1.45, 1.72,0.34,2.09]
data_dict['median']= [1.43, 1.50, 1.29, 1.41,0.43,1.75]
dataset = pd.DataFrame(data_dict)

# Data for the second subplot
data_dict1 = {}
data_dict1['category'] = ['Identity','QAT','SPTQ','Pruned','Distilled','DSPTQ']
data_dict1['lower'] = [0.94, 0.92, 0.53, 0.90, 0.39,0.32]
data_dict1['upper'] = [0.70, 0.50, 0.43, 0.68, 0.20,0.20]
data_dict1['median'] = [0.82, 0.65, 0.47, 0.80,0.25,0.23]
dataset1 = pd.DataFrame(data_dict1)

# Data for the third subplot
data_dict2 = {}
data_dict2['category'] = ['Identity','QAT','SPTQ','Pruned','Distilled','DSPTQ']
data_dict2['lower'] = [0.23, 0.16, 0.09, 0.23, 0.09,0.05]
data_dict2['upper'] = [0.23, 0.16, 0.08, 0.23, 0.07,0.05]
data_dict2['median'] = [0.23, 0.16, 0.08,0.23, 0.08,0.05]
dataset2 = pd.DataFrame(data_dict2)

# Data for the third subplot
data_dict3 = {}
data_dict3['category'] = ['Identity','QAT','SPTQ','Pruned','Distilled','DSPTQ']
data_dict3['lower'] = [2.18, 2.18, 2.18, 2.19, 2.19, 2.75]
data_dict3['upper'] = [3.52, 6.06, 3.53, 3.53, 3.51, 3.27]
data_dict3['median'] = [2.85, 2.85, 2.86, 2.86,2.85, 3.01]
dataset3 = pd.DataFrame(data_dict3)
# Create subplots
fig, axs = plt.subplots(1, 4, figsize=(15, 5))

# Plot for the first subplot
axs[0].set_title('Mobile (All subjects)')
for lower, upper, median, y in zip(dataset['lower'], dataset['upper'], dataset['median'], range(len(dataset))):
    axs[0].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[0].plot(median, y, 'o', color='#f44336')
axs[0].set_yticks(range(len(dataset)))
axs[0].set_yticklabels(dataset['category'])
axs[0].set_xlabel('MEIP Speedup/MESP slowdown')
axs[0].set_xlim(0, 6.5)

# Plot for the second subplot
axs[1].set_title('Edge (All subjects)')
for lower, upper, median, y in zip(dataset1['lower'], dataset1['upper'], dataset1['median'], range(len(dataset1))):
    axs[1].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[1].plot(median, y, 'o', color='#f44336')
axs[1].set_yticks(range(len(dataset1)))
axs[1].set_yticklabels(dataset1['category'])
axs[1].set_xlabel('MEIP/MESP Slowdown')
axs[1].set_xlim(0, 6.5)

# Plot for the third subplot
axs[2].set_title('Cloud (Textual subjects)')
for lower, upper, median, y in zip(dataset2['lower'], dataset2['upper'], dataset2['median'], range(len(dataset2))):
    axs[2].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[2].plot(median, y, 'o', color='#f44336')
axs[2].set_yticks(range(len(dataset2)))
axs[2].set_yticklabels(dataset2['category'])
axs[2].set_xlabel('MEIP/MESP Slowdown')
axs[2].set_xlim(0, 6.5)

# Plot for the third subplot
axs[3].set_title('Cloud (Image subjects)')
for lower, upper, median, y in zip(dataset3['lower'], dataset3['upper'], dataset3['median'], range(len(dataset3))):
    axs[3].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[3].plot(median, y, 'o', color='#f44336')
axs[3].set_yticks(range(len(dataset3)))
axs[3].set_yticklabels(dataset3['category'])
axs[3].set_xlabel('MEIP/MESP Speedup')
axs[3].set_xlim(0, 6.5)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
fig.savefig('MEIP_MESP_Speedup_Slowdown.pdf', bbox_inches='tight',format='pdf')
# Out:
# <ipython-input-3-27fc552dbee1>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[0].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-3-27fc552dbee1>:51: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[1].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-3-27fc552dbee1>:61: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[2].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-3-27fc552dbee1>:71: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for the first subplot
data_dict = {}
data_dict['category'] = ['Identity','QAT','SPTQ','Pruned','Distilled','DSPTQ']
data_dict['lower'] = [1.11, 1.18, 1.14, 1.20,0.63,1.14]
data_dict['upper'] = [1.72, 1.97, 1.45, 1.72,0.34,2.09]
data_dict['median']= [1.43, 1.50, 1.29, 1.41,0.43,1.75]
dataset = pd.DataFrame(data_dict)

# Data for the second subplot
data_dict1 = {}
data_dict1['category'] = ['Identity','QAT','SPTQ','Pruned','Distilled','DSPTQ']
data_dict1['lower'] = [0.94, 0.92, 0.53, 0.90, 0.39,0.32]
data_dict1['upper'] = [0.70, 0.50, 0.43, 0.68, 0.20,0.20]
data_dict1['median'] = [0.82, 0.65, 0.47, 0.80,0.25,0.23]
dataset1 = pd.DataFrame(data_dict1)

# Data for the third subplot
data_dict2 = {}
data_dict2['category'] = ['Identity','QAT','SPTQ','Pruned','Distilled','DSPTQ']
data_dict2['lower'] = [0.23, 0.16, 0.09, 0.23, 0.09,0.05]
data_dict2['upper'] = [0.23, 0.16, 0.08, 0.23, 0.07,0.05]
data_dict2['median'] = [0.23, 0.16, 0.08,0.23, 0.08,0.05]
dataset2 = pd.DataFrame(data_dict2)

# Data for the third subplot
data_dict3 = {}
data_dict3['category'] = ['Identity','QAT','SPTQ','Pruned','Distilled','DSPTQ']
data_dict3['lower'] = [2.18, 2.18, 2.18, 2.19, 2.19, 2.75]
data_dict3['upper'] = [3.52, 6.06, 3.53, 3.53, 3.51, 3.27]
data_dict3['median'] = [2.85, 2.85, 2.86, 2.86,2.85, 3.01]
dataset3 = pd.DataFrame(data_dict3)
# Create subplots
fig, axs = plt.subplots(1, 4, figsize=(12, 4))

# Plot for the first subplot
axs[0].set_title('Mobile (All subject models)')
for lower, upper, median, y in zip(dataset['lower'], dataset['upper'], dataset['median'], range(len(dataset))):
    axs[0].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[0].plot(median, y, 'o', color='#f44336')

axs[0].axvline(x=1, color='red', linestyle='--')
axs[0].set_yticks(range(len(dataset)))
axs[0].set_yticklabels(dataset['category'])
axs[0].set_xlabel('MEIP/MESP Speedup/Slowdown')
axs[0].set_xlim(0, 6.5)

# Plot for the second subplot
axs[1].set_title('Edge (All subject models)')
for lower, upper, median, y in zip(dataset1['lower'], dataset1['upper'], dataset1['median'], range(len(dataset1))):
    axs[1].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[1].plot(median, y, 'o', color='#f44336')
axs[1].set_yticks(range(len(dataset1)))
axs[1].set_yticklabels(dataset1['category'])
axs[1].set_xlabel('MEIP/MESP Slowdown')
axs[1].set_xlim(0, 6.5)
axs[1].axvline(x=1, color='red', linestyle='--')

# Plot for the third subplot
axs[2].set_title('Cloud (Textual subjects models)')
for lower, upper, median, y in zip(dataset2['lower'], dataset2['upper'], dataset2['median'], range(len(dataset2))):
    axs[2].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[2].plot(median, y, 'o', color='#f44336')
axs[2].set_yticks(range(len(dataset2)))
axs[2].set_yticklabels(dataset2['category'])
axs[2].set_xlabel('MEIP/MESP Slowdown')
axs[2].set_xlim(0, 6.5)
axs[2].axvline(x=1, color='red', linestyle='--')

# Plot for the third subplot
axs[3].set_title('Cloud (Image subjects models)')
for lower, upper, median, y in zip(dataset3['lower'], dataset3['upper'], dataset3['median'], range(len(dataset3))):
    axs[3].plot((lower, upper), (y, y), 'ro-', color='orange')
    axs[3].plot(median, y, 'o', color='#f44336')
axs[3].set_yticks(range(len(dataset3)))
axs[3].set_yticklabels(dataset3['category'])
axs[3].set_xlabel('MEIP/MESP Speedup')
axs[3].set_xlim(0, 6.5)
axs[3].axvline(x=1, color='red', linestyle='--')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
fig.savefig('MEIP_MESP_Speedup_Slowdown.pdf', bbox_inches='tight',format='pdf')
# Out:
# <ipython-input-3-64db635b6d02>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[0].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-3-64db635b6d02>:53: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[1].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-3-64db635b6d02>:64: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   axs[2].plot((lower, upper), (y, y), 'ro-', color='orange')
# <ipython-input-3-64db635b6d02>:75: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
# ...
